# %% [markdown]
# # Capstone Project Notebook
# ### (To get IBM Data Science Professional Certificate)
#
# ![alt text](Img01.PNG "Data Science")
#
# This notebook will show the code to scrape the following Wikipedia page, https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M in order to obtain the data that is in the table of postal codes and to transform the data into a pandas dataframe.
#
# > Given a city like the City of Toronto, you will segment it into different neighborhoods using the geographical coordinates of the center of each neighborhood, and then using a combination of location data and machine learning, you will group the neighbourhoods into clusters

# %% [markdown]
# ### First section

# %%
import pandas as pd
import numpy as np

# Read source
tmp = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')

# The first webpage table has the needed information for this project
postal_codes_tmp = tmp[0]

# Filter records which Borough == Not assigned
na_filter = postal_codes_tmp['Borough'] != 'Not assigned'
filtered_postal_codes = postal_codes_tmp[na_filter]

# More than one neighborhood can exist in one postal code area. For such cases, neighborhoods will be shown in the same row separated with a comma (e.g. M1C, M3J, M5A, etc.)
postal_codes = filtered_postal_codes.groupby(['Postcode', 'Borough']).agg([(', '.join)]).reset_index()

# Rename column headers
postal_codes.columns = ['PostalCode', 'Borough', 'Neighborhood']

# Whenever the Neighborhood is Not assigned, the Borough name should be used as the Neighborhood value (e.g. M7A)
postal_codes.Neighborhood.replace('Not assigned',postal_codes.Borough,inplace=True)

print('Pandas is awesome to read html tables!')
postal_codes.head()
# Out:
# Pandas is awesome to read html tables!
#   PostalCode      Borough                            Neighborhood
# 0        M1B  Scarborough                          Rouge, Malvern
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae

# %%
# Regardless the information is shown above, here you can check the number of the dataframe rows
print(str(postal_codes.shape[0]) + ' dataframe rows.')
# Out:
# 103 dataframe rows.

# %% [markdown]
# ### Second section

# %%
# Read coordinates source
coordinates = pd.read_csv('Geospatial_Coordinates.csv')

# Rename column headers
coordinates.columns = ['PostalCode', 'Latitude', 'Longitude']

toronto_data = pd.merge(postal_codes, coordinates, how='inner', left_on = 'PostalCode', right_on = 'PostalCode')
print(toronto_data.shape)
toronto_data.head()
# Out:
# (103, 5)
#   PostalCode      Borough                            Neighborhood   Latitude  \
# 0        M1B  Scarborough                          Rouge, Malvern  43.806686
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3        M1G  Scarborough                                  Woburn  43.770992
# 4        M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %% [markdown]
# ### Third section

# %% [markdown]
# #### Installing all the needed libraries

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# #### Verifying number of boroughs and neighborhoods

# %%
print('The Toronto dataframe has {} boroughs and {} neighborhoods.'.format(
        len(toronto_data['Borough'].unique()),
        toronto_data.shape[0]
    )
)
# Out:
# The Toronto dataframe has 11 boroughs and 103 neighborhoods.

# %% [markdown]
# #### Get Toronto latitude and longitud to build the map

# %%
address = 'Toronto, Canada'

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))

# create map of New York using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(toronto_data['Latitude'], toronto_data['Longitude'], toronto_data['Borough'], toronto_data['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Credentials setup and function to get venues by neighborhood in Toronto

# %%
# Define Foursquare Credentials and Version
CLIENT_ID = '020DHIJQ5OJ4YZ12HXXY4O0D33CXV4OT0QXK25QO3Y03IK1I'
CLIENT_SECRET = 'P3SIW32METMPEVCC1WEZ3DXWQEFVGA2YZC5ELTDWT2FSYVW4'
VERSION = '20180605'
LIMIT = 100

def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# #### Get Toronto venues using defined function
# ##### 278 uniques categories in 2,264 venues (7 columns)

# %%
toronto_venues = getNearbyVenues(names=toronto_data['Neighborhood'],
                                   latitudes=toronto_data['Latitude'],
                                   longitudes=toronto_data['Longitude']
                                  )

print(str(toronto_venues.shape[0]) + ' venues with ' + str(toronto_venues.shape[1]) + ' columns')
#toronto_venues.head()

#toronto_venues.groupby('Neighborhood').count()

print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# Rouge, Malvern
# Highland Creek, Rouge Hill, Port Union
# Guildwood, Morningside, West Hill
# Woburn
# Cedarbrae
# Scarborough Village
# East Birchmount Park, Ionview, Kennedy Park
# Clairlea, Golden Mile, Oakridge
# Cliffcrest, Cliffside, Scarborough Village West
# Birch Cliff, Cliffside West
# Dorset Park, Scarborough Town Centre, Wexford Heights
# Maryvale, Wexford
# Agincourt
# Clarks Corners, Sullivan, Tam O'Shanter
# Agincourt North, L'Amoreaux East, Milliken, Steeles East
# L'Amoreaux West
# Upper Rouge
# Hillcrest Village
# Fairview, Henry Farm, Oriole
# Bayview Village
# Silver Hills, York Mills
# Newtonbrook, Willowdale
# Willowdale South
# York Mills West
# Willowdale West
# Parkwoods
# Don Mills North
# Flemingdon Park, Don Mills South
# Bathurst Manor, Downsview North, Wilson Heights
# Northwood Park, York University
# CFB Toronto, Downsview East
# Downsview West
# Downsview Central
# Downsview Northwest
# Victoria Village
# Woodbine Gardens, Parkview Hill
# Woodbine Heights
# The Beaches
# Leaside
# Thorncliffe Park
# East Toronto
# The Danforth West, Riverdale
# The Beaches West, India Bazaar
# Studio District
# Lawrence Park
# Davisville North
# North Toronto West
# Davisville
# Moore Park, Summerhill East
# Deer Park, Forest Hill SE, Rathnelly, South Hill, Summerhill West
# Rosedale
# Cabbagetown, St. James Town
# Church and Wellesley
# Harbourfront, Regent Park
# Ryerson, Garden District
# St. James Town
# Berczy Park
# Central Bay Street
# Adelaide, King, Richmond
# Harbourfront East, Toronto Islands, Union Station
# Design Exchange, Toronto Dominion Centre
# Commerce Court, Victoria Hotel
# Bedford Park, Lawrence Manor East
# Roselawn
# Forest Hill North, Forest Hill West
# The Annex, North Midtown, Yorkville
# Harbord, University of Toronto
# Chinatown, Grange Park, Kensington Market
# CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara
# Stn A PO Boxes 25 The Esplanade
# First Canadian Place, Underground city
# Lawrence Heights, Lawrence Manor
# Glencairn
# Humewood-Cedarvale
# Caledonia-Fairbanks
# Christie
# Dovercourt Village, Dufferin
# Little Portugal, Trinity
# Brockton, Exhibition Place, Parkdale Village
# Downsview, North Park, Upwood Park
# Del Ray, Keelesdale, Mount Dennis, Silverthorn
# The Junction North, Runnymede
# High Park, The Junction South
# Parkdale, Roncesvalles
# Runnymede, Swansea
# Queen's Park
# Canada Post Gateway Processing Centre
# Business Reply Mail Processing Centre 969 Eastern
# Humber Bay Shores, Mimico South, New Toronto
# Alderwood, Long Branch
# The Kingsway, Montgomery Road, Old Mill North
# Humber Bay, King's Mill Park, Kingsway Park South East, Mimico NE, Old Mill South, The Queensway East, Royal York South East, Sunnylea
# Kingsway Park South West, Mimico NW, The Queensway West, Royal York South West, South of Bloor
# Islington Avenue
# Cloverdale, Islington, Martin Grove, Princess Gardens, West Deane Park
# Bloordale Gardens, Eringate, Markland Wood, Old Burnhamthorpe
# Humber Summit
# Emery, Humberlea
# Weston
# Westmount
# Kingsview Village, Martin Grove Gardens, Richview Gardens, St. Phillips
# Albion Gardens, Beaumond Heights, Humbergate, Jamestown, Mount Olive, Silverstone, South Steeles, Thistletown
# Northwest
# 2264 venues with 7 columns
# There are 278 uniques categories.

# %% [markdown]
# ##### One hot encoding
# ###### 278 uniques categories in 2,264 venues (7 columns). 100 different neighborhoods

# %%
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

# toronto_onehot.head()

print(toronto_onehot.shape)

toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
# print(toronto_grouped)

print(toronto_grouped.shape)
# Out:
# (2264, 278)
# (100, 278)

# %% [markdown]
# ##### 5 most common venues per neighborhood

# %%
num_top_venues = 5

for hood in toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Adelaide, King, Richmond----
#              venue  freq
# 0      Coffee Shop  0.07
# 1             Café  0.05
# 2       Steakhouse  0.04
# 3              Bar  0.04
# 4  Thai Restaurant  0.04
#
#
# ----Agincourt----
#                 venue  freq
# 0        Skating Rink  0.25
# 1      Breakfast Spot  0.25
# 2              Lounge  0.25
# 3      Clothing Store  0.25
# 4  Miscellaneous Shop  0.00
#
#
# ----Agincourt North, L'Amoreaux East, Milliken, Steeles East----
#                        venue  freq
# 0                 Playground  0.33
# 1                        Gym  0.33
# 2                       Park  0.33
# 3                Yoga Studio  0.00
# 4  Middle Eastern Restaurant  0.00
#
#
# ----Albion Gardens, Beaumond Heights, Humbergate, Jamestown, Mount Olive, Silverstone, South Steeles, Thistletown----
#                   venue  freq
# 0         Grocery Store  0.22
# 1              Pharmacy  0.11
# 2  Fast Food Restaurant  0.11
# 3        Sandwich Place  0.11
# 4   Fried Chicken Joint  0.11
#
#
# ----Alderwood, Long Branch----
#          venue  freq
# 0  Pizza Place  0.22
# 1         Pool  0.11
# 2          Pub  0.11
# 3     Pharmacy  0.11
# 4          Gym  0.11
#
#
# ----Bathurst Manor, Downsview North, Wilson Heights----
#                        venue  freq
# 0                Coffee Shop  0.11
# 1  Middle Eastern Restaurant  0.06
# 2                Supermarket  0.06
# 3         Frozen Yogurt Shop  0.06
# 4                 Restaurant  0.06
#
#
# ----Bayview Village----
#                  venue  freq
# 0                 Café  0.25
# 1  Japanese Restaurant  0.25
# 2                 Bank  0.25
# 3   Chinese Restaurant  0.25
# 4        Moving Target  0.00
#
#
# ----Bedford Park, Lawrence Manor East----
#                  venue  freq
# 0   Italian Restaurant  0.09
# 1          Coffee Shop  0.09
# 2         Liquor Store  0.05
# 3                 Café  0.05
# 4  Japanese Restaurant  0.05
#
#
# ----Berczy Park----
#             venue  freq
# 0     Coffee Shop  0.07
# 1          Bakery  0.05
# 2    Cocktail Bar  0.05
# 3     Cheese Shop  0.04
# 4  Farmers Market  0.04
#
#
# ----Birch Cliff, Cliffside West----
#                    venue  freq
# 0        College Stadium  0.25
# 1  General Entertainment  0.25
# 2           Skating Rink  0.25
# 3                   Café  0.25
# 4      Mobile Phone Shop  0.00
#
#
# ----Bloordale Gardens, Eringate, Markland Wood, Old Burnhamthorpe----
#             venue  freq
# 0        Pharmacy  0.11
# 1     Coffee Shop  0.11
# 2      Beer Store  0.11
# 3    Liquor Store  0.11
# 4  Shopping Plaza  0.11
#
#
# ----Brockton, Exhibition Place, Parkdale Village----
#                    venue  freq
# 0            Coffee Shop  0.08
# 1  Performing Arts Venue  0.08
# 2         Breakfast Spot  0.08
# 3                   Café  0.08
# 4           Intersection  0.04
#
#
# ----Business Reply Mail Processing Centre 969 Eastern----
#                   venue  freq
# 0  Gym / Fitness Center  0.09
# 1    Light Rail Station  0.09
# 2           Yoga Studio  0.05
# 3      Recording Studio  0.05
# 4            Smoke Shop  0.05
#
#
# ----CFB Toronto, Downsview East----
#                        venue  freq
# 0                    Airport   0.5
# 1                       Park   0.5
# 2                Yoga Studio   0.0
# 3  Middle Eastern Restaurant   0.0
# 4                      Motel   0.0
#
#
# ----CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara----
#               venue  freq
# 0  Airport Terminal  0.12
# 1    Airport Lounge  0.12
# 2   Airport Service  0.12
# 3   Harbor / Marina  0.06
# 4       Coffee Shop  0.06
#
#
# ----Cabbagetown, St. James Town----
#                 venue  freq
# 0         Coffee Shop  0.09
# 1  Italian Restaurant  0.05
# 2         Pizza Place  0.05
# 3          Restaurant  0.05
# 4                 Pub  0.05
#
#
# ----Caledonia-Fairbanks----
#                   venue  freq
# 0                  Park  0.33
# 1         Women's Store  0.17
# 2                Market  0.17
# 3  Fast Food Restaurant  0.17
# 4              Pharmacy  0.17
#
#
# ----Canada Post Gateway Processing Centre----
#                       venue  freq
# 0               Coffee Shop   0.2
# 1                     Hotel   0.2
# 2  Mediterranean Restaurant   0.1
# 3            Sandwich Place   0.1
# 4       Fried Chicken Joint   0.1
#
#
# ----Cedarbrae----
#                   venue  freq
# 0  Caribbean Restaurant  0.14
# 1   Fried Chicken Joint  0.14
# 2                  Bank  0.14
# 3    Athletics & Sports  0.14
# 4       Thai Restaurant  0.14
#
#
# ----Central Bay Street----
#                 venue  freq
# 0         Coffee Shop  0.15
# 1  Italian Restaurant  0.05
# 2                Café  0.05
# 3      Ice Cream Shop  0.05
# 4        Burger Joint  0.03
#
#
# ----Chinatown, Grange Park, Kensington Market----
#                            venue  freq
# 0                           Café  0.08
# 1  Vegetarian / Vegan Restaurant  0.06
# 2                            Bar  0.05
# 3          Vietnamese Restaurant  0.05
# 4             Mexican Restaurant  0.04
#
#
# ----Christie----
#                venue  freq
# 0      Grocery Store  0.19
# 1               Café  0.19
# 2               Park  0.12
# 3         Restaurant  0.06
# 4  Convenience Store  0.06
#
#
# ----Church and Wellesley----
#                  venue  freq
# 0          Coffee Shop  0.07
# 1              Gay Bar  0.06
# 2  Japanese Restaurant  0.06
# 3     Sushi Restaurant  0.05
# 4           Restaurant  0.03
#
#
# ----Clairlea, Golden Mile, Oakridge----
#                   venue  freq
# 0              Bus Line  0.22
# 1                Bakery  0.22
# 2  Fast Food Restaurant  0.11
# 3          Soccer Field  0.11
# 4                  Park  0.11
#
#
# ----Clarks Corners, Sullivan, Tam O'Shanter----
#                   venue  freq
# 0           Pizza Place   0.2
# 1         Shopping Mall   0.1
# 2  Fast Food Restaurant   0.1
# 3    Italian Restaurant   0.1
# 4   Fried Chicken Joint   0.1
#
#
# ----Cliffcrest, Cliffside, Scarborough Village West----
#                  venue  freq
# 0  American Restaurant   0.5
# 1                Motel   0.5
# 2               Museum   0.0
# 3        Movie Theater   0.0
# 4  Monument / Landmark   0.0
#
#
# ----Cloverdale, Islington, Martin Grove, Princess Gardens, West Deane Park----
#                 venue  freq
# 0                Bank   0.5
# 1         Golf Course   0.5
# 2         Yoga Studio   0.0
# 3  Miscellaneous Shop   0.0
# 4               Motel   0.0
#
#
# ----Commerce Court, Victoria Hotel----
#                  venue  freq
# 0          Coffee Shop  0.09
# 1                 Café  0.06
# 2                Hotel  0.06
# 3           Restaurant  0.04
# 4  American Restaurant  0.04
#
#
# ----Davisville----
#               venue  freq
# 0       Pizza Place  0.08
# 1      Dessert Shop  0.08
# 2    Sandwich Place  0.08
# 3              Café  0.06
# 4  Sushi Restaurant  0.06
#
#
# ----Davisville North----
#                venue  freq
# 0     Clothing Store  0.14
# 1                Gym  0.14
# 2  Food & Drink Shop  0.14
# 3              Hotel  0.14
# 4     Sandwich Place  0.14
#
#
# ----Deer Park, Forest Hill SE, Rathnelly, South Hill, Summerhill West----
#           venue  freq
# 0   Coffee Shop  0.12
# 1           Pub  0.12
# 2    Bagel Shop  0.06
# 3  Liquor Store  0.06
# 4    Sports Bar  0.06
#
#
# ----Del Ray, Keelesdale, Mount Dennis, Silverthorn----
#                venue  freq
# 0     Sandwich Place  0.25
# 1         Restaurant  0.25
# 2        Coffee Shop  0.25
# 3  Convenience Store  0.25
# 4        Yoga Studio  0.00
#
#
# ----Design Exchange, Toronto Dominion Centre----
#                 venue  freq
# 0         Coffee Shop  0.13
# 1                Café  0.08
# 2               Hotel  0.06
# 3  Italian Restaurant  0.04
# 4          Restaurant  0.04
#
#
# ----Don Mills North----
#                   venue  freq
# 0   Japanese Restaurant  0.17
# 1  Gym / Fitness Center  0.17
# 2  Caribbean Restaurant  0.17
# 3        Baseball Field  0.17
# 4      Basketball Court  0.17
#
#
# ----Dorset Park, Scarborough Town Centre, Wexford Heights----
#                        venue  freq
# 0          Indian Restaurant  0.29
# 1                  Pet Store  0.14
# 2      Vietnamese Restaurant  0.14
# 3         Chinese Restaurant  0.14
# 4  Latin American Restaurant  0.14
#
#
# ----Dovercourt Village, Dufferin----
#          venue  freq
# 0     Pharmacy  0.11
# 1       Bakery  0.11
# 2  Supermarket  0.11
# 3     Bus Stop  0.05
# 4      Brewery  0.05
#
#
# ----Downsview Central----
#               venue  freq
# 0  Business Service  0.25
# 1      Home Service  0.25
# 2    Baseball Field  0.25
# 3        Food Truck  0.25
# 4       Yoga Studio  0.00
#
#
# ----Downsview Northwest----
#                   venue  freq
# 0        Discount Store  0.25
# 1  Gym / Fitness Center  0.25
# 2         Grocery Store  0.25
# 3          Liquor Store  0.25
# 4           Yoga Studio  0.00
#
#
# ----Downsview West----
#            venue  freq
# 0  Grocery Store  0.33
# 1           Bank  0.17
# 2           Park  0.17
# 3  Shopping Mall  0.17
# 4          Hotel  0.17
#
#
# ----Downsview, North Park, Upwood Park----
#                         venue  freq
# 0                      Bakery  0.33
# 1                        Park  0.33
# 2  Construction & Landscaping  0.33
# 3                 Yoga Studio  0.00
# 4          Miscellaneous Shop  0.00
#
#
# ----East Birchmount Park, Ionview, Kennedy Park----
#                venue  freq
# 0   Department Store  0.25
# 1     Discount Store  0.25
# 2         Playground  0.25
# 3        Coffee Shop  0.25
# 4  Mobile Phone Shop  0.00
#
#
# ----East Toronto----
#                venue  freq
# 0               Park   0.4
# 1        Pizza Place   0.2
# 2        Coffee Shop   0.2
# 3  Convenience Store   0.2
# 4        Yoga Studio   0.0
#
#
# ----Emery, Humberlea----
#                     venue  freq
# 0  Furniture / Home Store   0.5
# 1          Baseball Field   0.5
# 2                  Market   0.0
# 3           Movie Theater   0.0
# 4                   Motel   0.0
#
#
# ----Fairview, Henry Farm, Oriole----
#                   venue  freq
# 0        Clothing Store  0.15
# 1           Coffee Shop  0.08
# 2  Fast Food Restaurant  0.08
# 3         Women's Store  0.05
# 4                Bakery  0.03
#
#
# ----First Canadian Place, Underground city----
#          venue  freq
# 0  Coffee Shop  0.09
# 1         Café  0.07
# 2        Hotel  0.04
# 3   Steakhouse  0.04
# 4       Bakery  0.03
#
#
# ----Flemingdon Park, Don Mills South----
#               venue  freq
# 0  Asian Restaurant  0.09
# 1        Beer Store  0.09
# 2               Gym  0.09
# 3       Coffee Shop  0.09
# 4    Discount Store  0.05
#
#
# ----Forest Hill North, Forest Hill West----
#               venue  freq
# 0             Trail   0.2
# 1     Jewelry Store   0.2
# 2              Park   0.2
# 3  Sushi Restaurant   0.2
# 4          Bus Line   0.2
#
#
# ----Glencairn----
#                  venue  freq
# 0  Japanese Restaurant  0.25
# 1                 Park  0.25
# 2     Asian Restaurant  0.25
# 3                  Pub  0.25
# 4   Miscellaneous Shop  0.00
#
#
# ----Guildwood, Morningside, West Hill----
#                  venue  freq
# 0          Pizza Place  0.12
# 1  Rental Car Location  0.12
# 2                  Spa  0.12
# 3       Breakfast Spot  0.12
# 4    Electronics Store  0.12
#
#
# ----Harbord, University of Toronto----
#                  venue  freq
# 0                 Café  0.11
# 1               Bakery  0.06
# 2  Japanese Restaurant  0.06
# 3            Bookstore  0.06
# 4           Restaurant  0.06
#
#
# ----Harbourfront East, Toronto Islands, Union Station----
#                 venue  freq
# 0         Coffee Shop  0.11
# 1               Hotel  0.05
# 2            Aquarium  0.05
# 3  Italian Restaurant  0.04
# 4                Café  0.04
#
#
# ----Harbourfront, Regent Park----
#                   venue  freq
# 0           Coffee Shop  0.16
# 1                Bakery  0.06
# 2                  Park  0.06
# 3                   Pub  0.06
# 4  Gym / Fitness Center  0.04
#
#
# ----High Park, The Junction South----
#                  venue  freq
# 0                  Bar  0.09
# 1                 Café  0.09
# 2   Mexican Restaurant  0.09
# 3               Bakery  0.05
# 4  Arts & Crafts Store  0.05
#
#
# ----Highland Creek, Rouge Hill, Port Union----
#                  venue  freq
# 0                  Bar   1.0
# 1          Yoga Studio   0.0
# 2   Miscellaneous Shop   0.0
# 3                Motel   0.0
# 4  Monument / Landmark   0.0
#
#
# ----Hillcrest Village----
#                       venue  freq
# 0      Fast Food Restaurant  0.17
# 1  Mediterranean Restaurant  0.17
# 2        Athletics & Sports  0.17
# 3                      Pool  0.17
# 4                   Dog Run  0.17
#
#
# ----Humber Bay Shores, Mimico South, New Toronto----
#                 venue  freq
# 0           Pet Store  0.07
# 1         Coffee Shop  0.07
# 2  Seafood Restaurant  0.07
# 3        Liquor Store  0.07
# 4      Sandwich Place  0.07
#
#
# ----Humber Bay, King's Mill Park, Kingsway Park South East, Mimico NE, Old Mill South, The Queensway East, Royal York South East, Sunnylea----
#                        venue  freq
# 0                       Park  0.33
# 1                       Pool  0.33
# 2             Baseball Field  0.33
# 3                Yoga Studio  0.00
# 4  Middle Eastern Restaurant  0.00
#
#
# ----Humber Summit----
#                        venue  freq
# 0        Empanada Restaurant   1.0
# 1                Yoga Studio   0.0
# 2  Middle Eastern Restaurant   0.0
# 3                      Motel   0.0
# 4        Monument / Landmark   0.0
#
#
# ----Humewood-Cedarvale----
#           venue  freq
# 0         Field  0.25
# 1         Trail  0.25
# 2  Hockey Arena  0.25
# 3       Dog Run  0.25
# 4         Motel  0.00
#
#
# ----Kingsview Village, Martin Grove Gardens, Richview Gardens, St. Phillips----
#                 venue  freq
# 0         Pizza Place  0.25
# 1                Park  0.25
# 2            Bus Line  0.25
# 3   Mobile Phone Shop  0.25
# 4  Miscellaneous Shop  0.00
#
#
# ----Kingsway Park South West, Mimico NW, The Queensway West, Royal York South West, South of Bloor----
#                     venue  freq
# 0             Social Club  0.07
# 1  Thrift / Vintage Store  0.07
# 2          Discount Store  0.07
# 3          Sandwich Place  0.07
# 4    Fast Food Restaurant  0.07
#
#
# ----L'Amoreaux West----
#                     venue  freq
# 0    Fast Food Restaurant  0.12
# 1           Grocery Store  0.12
# 2      Chinese Restaurant  0.12
# 3  Thrift / Vintage Store  0.06
# 4                Pharmacy  0.06
#
#
# ----Lawrence Heights, Lawrence Manor----
#                     venue  freq
# 0  Furniture / Home Store  0.23
# 1          Clothing Store  0.15
# 2           Women's Store  0.08
# 3             Coffee Shop  0.08
# 4             Event Space  0.08
#
#
# ----Lawrence Park----
#          venue  freq
# 0         Lake  0.25
# 1         Park  0.25
# 2  Swim School  0.25
# 3     Bus Line  0.25
# 4  Yoga Studio  0.00
#
#
# ----Leaside----
#                     venue  freq
# 0             Coffee Shop  0.12
# 1     Sporting Goods Shop  0.09
# 2            Burger Joint  0.06
# 3  Furniture / Home Store  0.06
# 4           Grocery Store  0.06
#
#
# ----Little Portugal, Trinity----
#                      venue  freq
# 0                      Bar  0.12
# 1              Coffee Shop  0.06
# 2         Asian Restaurant  0.05
# 3             Cocktail Bar  0.03
# 4  New American Restaurant  0.03
#
#
# ----Maryvale, Wexford----
#                        venue  freq
# 0  Middle Eastern Restaurant  0.29
# 1             Sandwich Place  0.14
# 2              Shopping Mall  0.14
# 3                Auto Garage  0.14
# 4             Breakfast Spot  0.14
#
#
# ----Moore Park, Summerhill East----
#                  venue  freq
# 0                Trail   0.5
# 1         Tennis Court   0.5
# 2          Yoga Studio   0.0
# 3                Motel   0.0
# 4  Monument / Landmark   0.0
#
#
# ----North Toronto West----
#                 venue  freq
# 0      Clothing Store  0.13
# 1         Coffee Shop  0.13
# 2         Yoga Studio  0.07
# 3                 Spa  0.07
# 4  Mexican Restaurant  0.07
#
#
# ----Northwest----
#                  venue  freq
# 0            Drugstore  0.33
# 1  Rental Car Location  0.33
# 2                  Bar  0.33
# 3        Moving Target  0.00
# 4                Motel  0.00
#
#
# ----Northwood Park, York University----
#                 venue  freq
# 0      Massage Studio   0.2
# 1  Miscellaneous Shop   0.2
# 2  Falafel Restaurant   0.2
# 3         Coffee Shop   0.2
# 4                 Bar   0.2
#
#
# ----Parkdale, Roncesvalles----
#                          venue  freq
# 0               Breakfast Spot  0.13
# 1                    Gift Shop  0.13
# 2                 Dessert Shop  0.07
# 3  Eastern European Restaurant  0.07
# 4                Movie Theater  0.07
#
#
# ----Parkwoods----
#                        venue  freq
# 0       Fast Food Restaurant  0.25
# 1                   Bus Stop  0.25
# 2                       Park  0.25
# 3          Food & Drink Shop  0.25
# 4  Middle Eastern Restaurant  0.00
#
#
# ----Queen's Park----
#          venue  freq
# 0  Coffee Shop  0.22
# 1          Gym  0.05
# 2        Diner  0.05
# 3         Park  0.05
# 4  Yoga Studio  0.02
#
#
# ----Rosedale----
#          venue  freq
# 0         Park   0.4
# 1     Building   0.2
# 2   Playground   0.2
# 3        Trail   0.2
# 4  Yoga Studio   0.0
#
#
# ----Roselawn----
#                              venue  freq
# 0                           Garden   1.0
# 1        Middle Eastern Restaurant   0.0
# 2                            Motel   0.0
# 3              Monument / Landmark   0.0
# 4  Molecular Gastronomy Restaurant   0.0
#
#
# ----Rouge, Malvern----
#                        venue  freq
# 0       Fast Food Restaurant   1.0
# 1                Yoga Studio   0.0
# 2  Middle Eastern Restaurant   0.0
# 3                      Motel   0.0
# 4        Monument / Landmark   0.0
#
#
# ----Runnymede, Swansea----
#                 venue  freq
# 0         Coffee Shop  0.08
# 1                Café  0.08
# 2         Pizza Place  0.08
# 3  Italian Restaurant  0.05
# 4    Sushi Restaurant  0.05
#
#
# ----Ryerson, Garden District----
#                   venue  freq
# 0           Coffee Shop  0.09
# 1        Clothing Store  0.07
# 2        Cosmetics Shop  0.04
# 3  Fast Food Restaurant  0.03
# 4                  Café  0.03
#
#
# ----Scarborough Village----
#                      venue  freq
# 0            Women's Store  0.33
# 1               Playground  0.33
# 2  Health & Beauty Service  0.33
# 3                 Wine Bar  0.00
# 4            Movie Theater  0.00
#
#
# ----Silver Hills, York Mills----
#                 venue  freq
# 0           Cafeteria   1.0
# 1         Yoga Studio   0.0
# 2  Miscellaneous Shop   0.0
# 3       Movie Theater   0.0
# 4               Motel   0.0
#
#
# ----St. James Town----
#             venue  freq
# 0     Coffee Shop  0.07
# 1           Hotel  0.05
# 2            Café  0.05
# 3      Restaurant  0.05
# 4  Cosmetics Shop  0.03
#
#
# ----Stn A PO Boxes 25 The Esplanade----
#                   venue  freq
# 0           Coffee Shop  0.10
# 1                  Café  0.04
# 2            Restaurant  0.04
# 3  Fast Food Restaurant  0.03
# 4    Seafood Restaurant  0.03
#
#
# ----Studio District----
#                  venue  freq
# 0                 Café  0.10
# 1          Coffee Shop  0.07
# 2               Bakery  0.05
# 3            Gastropub  0.05
# 4  American Restaurant  0.05
#
#
# ----The Annex, North Midtown, Yorkville----
#             venue  freq
# 0     Coffee Shop  0.12
# 1  Sandwich Place  0.12
# 2            Café  0.12
# 3     Pizza Place  0.08
# 4  History Museum  0.04
#
#
# ----The Beaches----
#                venue  freq
# 0              Trail  0.25
# 1  Health Food Store  0.25
# 2                Pub  0.25
# 3        Yoga Studio  0.00
# 4              Motel  0.00
#
#
# ----The Beaches West, India Bazaar----
#                 venue  freq
# 0                Park  0.10
# 1      Sandwich Place  0.10
# 2   Fish & Chips Shop  0.05
# 3  Italian Restaurant  0.05
# 4         Pizza Place  0.05
#
#
# ----The Danforth West, Riverdale----
#                     venue  freq
# 0        Greek Restaurant  0.22
# 1             Coffee Shop  0.10
# 2      Italian Restaurant  0.07
# 3  Furniture / Home Store  0.05
# 4          Ice Cream Shop  0.05
#
#
# ----The Junction North, Runnymede----
#                   venue  freq
# 0           Pizza Place   0.2
# 1     Convenience Store   0.2
# 2  Caribbean Restaurant   0.2
# 3               Brewery   0.2
# 4              Bus Line   0.2
#
#
# ----The Kingsway, Montgomery Road, Old Mill North----
#                 venue  freq
# 0                Park   0.5
# 1               River   0.5
# 2         Yoga Studio   0.0
# 3  Miscellaneous Shop   0.0
# 4               Motel   0.0
#
#
# ----Thorncliffe Park----
#                venue  freq
# 0  Indian Restaurant  0.15
# 1        Yoga Studio  0.08
# 2        Pizza Place  0.08
# 3               Park  0.08
# 4        Coffee Shop  0.08
#
#
# ----Victoria Village----
#                venue  freq
# 0        Pizza Place  0.17
# 1  French Restaurant  0.17
# 2       Intersection  0.17
# 3       Hockey Arena  0.17
# 4        Coffee Shop  0.17
#
#
# ----Westmount----
#                        venue  freq
# 0                Pizza Place  0.29
# 1             Sandwich Place  0.14
# 2               Intersection  0.14
# 3                Coffee Shop  0.14
# 4  Middle Eastern Restaurant  0.14
#
#
# ----Weston----
#                        venue  freq
# 0                       Park   1.0
# 1                Yoga Studio   0.0
# 2  Middle Eastern Restaurant   0.0
# 3                      Motel   0.0
# 4        Monument / Landmark   0.0
#
#
# ----Willowdale South----
#               venue  freq
# 0  Ramen Restaurant  0.08
# 1       Coffee Shop  0.08
# 2    Sandwich Place  0.06
# 3       Pizza Place  0.06
# 4              Café  0.06
#
#
# ----Willowdale West----
#             venue  freq
# 0        Pharmacy  0.17
# 1   Grocery Store  0.17
# 2  Discount Store  0.17
# 3         Butcher  0.17
# 4     Coffee Shop  0.17
#
#
# ----Woburn----
#                venue  freq
# 0        Coffee Shop  0.67
# 1  Korean Restaurant  0.33
# 2        Yoga Studio  0.00
# 3  Mobile Phone Shop  0.00
# 4      Movie Theater  0.00
#
#
# ----Woodbine Gardens, Parkview Hill----
#                   venue  freq
# 0           Pizza Place  0.17
# 1  Fast Food Restaurant  0.17
# 2              Pharmacy  0.08
# 3          Intersection  0.08
# 4                  Bank  0.08
#
#
# ----Woodbine Heights----
#               venue  freq
# 0          Pharmacy  0.12
# 1    Cosmetics Shop  0.12
# 2  Asian Restaurant  0.12
# 3      Dance Studio  0.12
# 4       Curling Ice  0.12
#
#
# ----York Mills West----
#                 venue  freq
# 0                Park  0.50
# 1                Bank  0.25
# 2   Convenience Store  0.25
# 3         Yoga Studio  0.00
# 4  Miscellaneous Shop  0.00

# %% [markdown]
# ##### Function to sort venues in descending order

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# ##### Top 10 venues per neighborhood

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                           Adelaide, King, Richmond           Coffee Shop
# 1                                          Agincourt                Lounge
# 2  Agincourt North, L'Amoreaux East, Milliken, St...                   Gym
# 3  Albion Gardens, Beaumond Heights, Humbergate, ...         Grocery Store
# 4                             Alderwood, Long Branch           Pizza Place
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                  Café   American Restaurant            Steakhouse
# 1        Clothing Store          Skating Rink        Breakfast Spot
# 2                  Park            Playground      Doner Restaurant
# 3   Fried Chicken Joint           Coffee Shop        Sandwich Place
# 4                   Gym           Coffee Shop              Pharmacy
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0       Thai Restaurant                   Bar      Sushi Restaurant
# 1         Women's Store            Donut Shop                 Diner
# 2          Dessert Shop    Dim Sum Restaurant                 Diner
# 3  Fast Food Restaurant            Beer Store           Pizza Place
# 4          Skating Rink        Sandwich Place                  Pool
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0      Asian Restaurant                Bakery                  Hotel
# 1        Discount Store              Dive Bar                Dog Run
# 2        Discount Store              Dive Bar                Dog Run
# 3              Pharmacy   Dumpling Restaurant              Drugstore
# 4                   Pub        Discount Store       Department Store

# %% [markdown]
# ##### Run k-means to cluster the neighborhood into 5 clusters

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 0, 2, 0, 0, 0, 0, 0, 0, 0], dtype=int32)

# %% [markdown]
# ##### Top 10 venues per neighborhood including cluster

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'ClusterL', kmeans.labels_)

toronto_merged = toronto_data

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
toronto_merged.fillna(0, inplace=True) # For some reason the labels were converted to float in the previous step
# toronto_merged.dtypes

toronto_merged['ClusterL'] = toronto_merged['ClusterL'].astype(int)

# %% [markdown]
# ##### Create map to show clusters

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['ClusterL']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##### Examine clusters
# ###### C1 : City zone

# %%
toronto_merged.loc[toronto_merged['ClusterL'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#               Borough  ClusterL      1st Most Common Venue  \
# 0         Scarborough         0       Fast Food Restaurant
# 2         Scarborough         0          Electronics Store
# 3         Scarborough         0                Coffee Shop
# 4         Scarborough         0        Fried Chicken Joint
# 5         Scarborough         0              Women's Store
# 6         Scarborough         0                Coffee Shop
# 7         Scarborough         0                     Bakery
# 8         Scarborough         0                      Motel
# 9         Scarborough         0      General Entertainment
# 10        Scarborough         0          Indian Restaurant
# 11        Scarborough         0  Middle Eastern Restaurant
# 12        Scarborough         0                     Lounge
# 13        Scarborough         0                Pizza Place
# 15        Scarborough         0              Grocery Store
# 16        Scarborough         0                          0
# 17         North York         0                    Dog Run
# 18         North York         0             Clothing Store
# 19         North York         0                       Café
# 21         North York         0                          0
# 22         North York         0                Coffee Shop
# 24         North York         0                   Pharmacy
# 25         North York         0                   Bus Stop
# 26         North York         0       Gym / Fitness Center
# 27         North York         0                        Gym
# 28         North York         0                Coffee Shop
# 29         North York         0         Falafel Restaurant
# 31         North York         0              Grocery Store
# 32         North York         0               Home Service
# 33         North York         0       Gym / Fitness Center
# 34         North York         0      Portuguese Restaurant
# 35          East York         0       Fast Food Restaurant
# 36          East York         0                       Park
# 37       East Toronto         0                      Trail
# 38          East York         0                Coffee Shop
# 39          East York         0          Indian Restaurant
# 41       East Toronto         0           Greek Restaurant
# 42       East Toronto         0             Sandwich Place
# 43       East Toronto         0                       Café
# 44    Central Toronto         0                       Park
# 45    Central Toronto         0                        Gym
# 46    Central Toronto         0                Coffee Shop
# 47    Central Toronto         0                Pizza Place
# 48    Central Toronto         0                      Trail
# 49    Central Toronto         0                Coffee Shop
# 51   Downtown Toronto         0                Coffee Shop
# 52   Downtown Toronto         0                Coffee Shop
# 53   Downtown Toronto         0                Coffee Shop
# 54   Downtown Toronto         0                Coffee Shop
# 55   Downtown Toronto         0                Coffee Shop
# 56   Downtown Toronto         0                Coffee Shop
# 57   Downtown Toronto         0                Coffee Shop
# 58   Downtown Toronto         0                Coffee Shop
# 59   Downtown Toronto         0                Coffee Shop
# 60   Downtown Toronto         0                Coffee Shop
# 61   Downtown Toronto         0                Coffee Shop
# 62         North York         0         Italian Restaurant
# 63    Central Toronto         0                     Garden
# 64    Central Toronto         0                       Park
# 65    Central Toronto         0                Coffee Shop
# 66   Downtown Toronto         0                       Café
# 67   Downtown Toronto         0                       Café
# 68   Downtown Toronto         0           Airport Terminal
# 69   Downtown Toronto         0                Coffee Shop
# 70   Downtown Toronto         0                Coffee Shop
# 71         North York         0     Furniture / Home Store
# 72         North York         0                       Park
# 73               York         0                      Trail
# 75   Downtown Toronto         0              Grocery Store
# 76       West Toronto         0                     Bakery
# 77       West Toronto         0                        Bar
# 78       West Toronto         0      Performing Arts Venue
# 80               York         0          Convenience Store
# 81               York         0                Pizza Place
# 82       West Toronto         0                        Bar
# 83       West Toronto         0             Breakfast Spot
# 84       West Toronto         0                Coffee Shop
# 85       Queen's Park         0                Coffee Shop
# 86        Mississauga         0                Coffee Shop
# 87       East Toronto         0       Gym / Fitness Center
# 88          Etobicoke         0                        Gym
# 89          Etobicoke         0                Pizza Place
# 92          Etobicoke         0              Grocery Store
# 93          Etobicoke         0                          0
# 94          Etobicoke         0                Golf Course
# 95          Etobicoke         0                       Park
# 97         North York         0     Furniture / Home Store
# 99          Etobicoke         0                Pizza Place
# 100         Etobicoke         0                       Park
# 101         Etobicoke         0              Grocery Store
# 102         Etobicoke         0                        Bar
#
#              2nd Most Common Venue 3rd Most Common Venue  \
# 0                    Women's Store            Donut Shop
# 2                              Spa   Rental Car Location
# 3                Korean Restaurant            Donut Shop
# 4                 Hakka Restaurant    Athletics & Sports
# 5          Health & Beauty Service            Playground
# 6                       Playground        Discount Store
# 7                         Bus Line                  Park
# 8              American Restaurant      Department Store
# 9                  College Stadium                  Café
# 10                       Pet Store    Chinese Restaurant
# 11                     Auto Garage        Breakfast Spot
# 12                  Clothing Store          Skating Rink
# 13             Fried Chicken Joint    Italian Restaurant
# 15              Chinese Restaurant  Fast Food Restaurant
# 16                               0                     0
# 17              Athletics & Sports  Fast Food Restaurant
# 18            Fast Food Restaurant           Coffee Shop
# 19             Japanese Restaurant                  Bank
# 21                               0                     0
# 22                Ramen Restaurant   Japanese Restaurant
# 24                   Grocery Store           Pizza Place
# 25                            Park  Fast Food Restaurant
# 26                  Baseball Field                  Café
# 27                     Coffee Shop      Asian Restaurant
# 28       Middle Eastern Restaurant           Pizza Place
# 29                     Coffee Shop        Massage Studio
# 31                            Park                  Bank
# 32                  Baseball Field            Food Truck
# 33                   Grocery Store          Liquor Store
# 34                     Coffee Shop     French Restaurant
# 35                     Pizza Place             Pet Store
# 36                  Cosmetics Shop          Skating Rink
# 37               Health Food Store                   Pub
# 38             Sporting Goods Shop         Grocery Store
# 39                     Yoga Studio           Supermarket
# 41                     Coffee Shop    Italian Restaurant
# 42                            Park            Board Shop
# 43                     Coffee Shop    Italian Restaurant
# 44                     Swim School              Bus Line
# 45                           Hotel        Clothing Store
# 46                  Clothing Store   Sporting Goods Shop
# 47                  Sandwich Place          Dessert Shop
# 48                    Tennis Court      Doner Restaurant
# 49                             Pub        Medical Center
# 51                          Bakery                   Pub
# 52             Japanese Restaurant               Gay Bar
# 53                          Bakery                   Pub
# 54                  Clothing Store        Cosmetics Shop
# 55                           Hotel            Restaurant
# 56                          Bakery          Cocktail Bar
# 57              Italian Restaurant                  Café
# 58                            Café   American Restaurant
# 59                        Aquarium                 Hotel
# 60                            Café                 Hotel
# 61                           Hotel                  Café
# 62                     Coffee Shop                   Pub
# 63                   Women's Store         Deli / Bodega
# 64                   Jewelry Store              Bus Line
# 65                  Sandwich Place                  Café
# 66                      Restaurant                Bakery
# 67   Vegetarian / Vegan Restaurant                   Bar
# 68                  Airport Lounge       Airport Service
# 69                            Café            Restaurant
# 70                            Café                 Hotel
# 71                  Clothing Store         Women's Store
# 72                Asian Restaurant   Japanese Restaurant
# 73                           Field          Hockey Arena
# 75                            Café                  Park
# 76                     Supermarket              Pharmacy
# 77                     Coffee Shop      Asian Restaurant
# 78                  Breakfast Spot                  Café
# 80                     Coffee Shop            Restaurant
# 81                        Bus Line               Brewery
# 82                            Café    Mexican Restaurant
# 83                       Gift Shop            Restaurant
# 84                     Pizza Place                  Café
# 85                            Park                   Gym
# 86                           Hotel   American Restaurant
# 87              Light Rail Station           Yoga Studio
# 88             American Restaurant                  Café
# 89                             Gym           Coffee Shop
# 92                   Burrito Place         Tanning Salon
# 93                               0                     0
# 94                            Bank         Women's Store
# 95                     Coffee Shop          Liquor Store
# 97                  Baseball Field    Dim Sum Restaurant
# 99              Chinese Restaurant           Coffee Shop
# 100                    Pizza Place     Mobile Phone Shop
# 101            Fried Chicken Joint           Coffee Shop
# 102            Rental Car Location             Drugstore
#
#          4th Most Common Venue        5th Most Common Venue  \
# 0           Dim Sum Restaurant                        Diner
# 2           Mexican Restaurant               Breakfast Spot
# 3           Dim Sum Restaurant                        Diner
# 4                       Bakery                         Bank
# 5             Doner Restaurant                 Dessert Shop
# 6             Department Store                Women's Store
# 7                Metro Station                  Bus Station
# 8                 Dessert Shop           Dim Sum Restaurant
# 9                 Skating Rink                Women's Store
# 10       Vietnamese Restaurant                  Gaming Cafe
# 11                      Bakery                Shopping Mall
# 12              Breakfast Spot                Women's Store
# 13                        Bank         Fast Food Restaurant
# 15      Thrift / Vintage Store          Japanese Restaurant
# 16                           0                            0
# 17                 Golf Course     Mediterranean Restaurant
# 18               Women's Store               Cosmetics Shop
# 19          Chinese Restaurant                Women's Store
# 21                           0                            0
# 22              Sandwich Place                         Café
# 24                 Coffee Shop                      Butcher
# 25           Food & Drink Shop             Doner Restaurant
# 26         Japanese Restaurant         Caribbean Restaurant
# 27                  Beer Store           Italian Restaurant
# 28          Frozen Yogurt Shop                   Restaurant
# 29          Miscellaneous Shop                          Bar
# 31               Shopping Mall                        Hotel
# 32            Business Service            Electronics Store
# 33              Discount Store                   Donut Shop
# 34                Hockey Arena                 Intersection
# 35          Athletics & Sports                    Gastropub
# 36                  Beer Store                  Curling Ice
# 37            Doner Restaurant                 Dessert Shop
# 38                Burger Joint       Furniture / Home Store
# 39                        Park                Grocery Store
# 41      Furniture / Home Store               Ice Cream Shop
# 42                         Pub                 Liquor Store
# 43                   Gastropub          American Restaurant
# 44                        Lake                Women's Store
# 45              Sandwich Place               Breakfast Spot
# 46        Fast Food Restaurant                        Diner
# 47                 Coffee Shop              Thai Restaurant
# 48                Dessert Shop           Dim Sum Restaurant
# 49         American Restaurant                   Bagel Shop
# 51                 Pizza Place                   Restaurant
# 52            Sushi Restaurant                   Restaurant
# 53                        Park               Breakfast Spot
# 54                        Café    Middle Eastern Restaurant
# 55                        Café               Cosmetics Shop
# 56                  Steakhouse                     Beer Bar
# 57              Ice Cream Shop               Sandwich Place
# 58                  Steakhouse              Thai Restaurant
# 59                        Café           Italian Restaurant
# 60          Italian Restaurant                   Restaurant
# 61         American Restaurant                   Restaurant
# 62                    Pharmacy                   Restaurant
# 63                Dessert Shop           Dim Sum Restaurant
# 64            Sushi Restaurant                        Trail
# 65                 Pizza Place                    BBQ Joint
# 66                         Bar          Japanese Restaurant
# 67       Vietnamese Restaurant           Chinese Restaurant
# 68             Harbor / Marina                  Coffee Shop
# 69                    Beer Bar         Fast Food Restaurant
# 70                  Steakhouse                          Gym
# 71                 Coffee Shop                     Boutique
# 72                         Pub                Women's Store
# 73                     Dog Run             Doner Restaurant
# 75          Italian Restaurant                  Coffee Shop
# 76                 Music Venue                         Café
# 77                        Café      New American Restaurant
# 78                 Coffee Shop                    Pet Store
# 80              Sandwich Place                Women's Store
# 81           Convenience Store         Caribbean Restaurant
# 82             Thai Restaurant       Furniture / Home Store
# 83            Cuban Restaurant  Eastern European Restaurant
# 84          Italian Restaurant             Sushi Restaurant
# 85                       Diner           College Auditorium
# 86   Middle Eastern Restaurant     Mediterranean Restaurant
# 87               Moving Target                      Brewery
# 88         Fried Chicken Joint               Sandwich Place
# 89                    Pharmacy                 Skating Rink
# 92              Sandwich Place              Supplement Shop
# 93                           0                            0
# 94            Doner Restaurant           Dim Sum Restaurant
# 95                  Beer Store               Shopping Plaza
# 97                       Diner               Discount Store
# 99              Sandwich Place                 Intersection
# 100                   Bus Line                Women's Store
# 101             Sandwich Place         Fast Food Restaurant
# 102              Women's Store           Dim Sum Restaurant
#
#            6th Most Common Venue        7th Most Common Venue  \
# 0                 Discount Store                     Dive Bar
# 2                 Medical Center                  Pizza Place
# 3                 Discount Store                     Dive Bar
# 4                Thai Restaurant         Caribbean Restaurant
# 5             Dim Sum Restaurant                        Diner
# 6               Doner Restaurant           Dim Sum Restaurant
# 7                   Soccer Field         Fast Food Restaurant
# 8                          Diner               Discount Store
# 9             Dim Sum Restaurant                        Diner
# 10     Latin American Restaurant                 Dessert Shop
# 11                Sandwich Place             Doner Restaurant
# 12                    Donut Shop                        Diner
# 13                  Noodle House                Shopping Mall
# 15                  Noodle House                  Coffee Shop
# 16                             0                            0
# 17                          Pool                Women's Store
# 18           Japanese Restaurant                   Food Court
# 19                       Dog Run                        Diner
# 21                             0                            0
# 22                   Pizza Place                   Restaurant
# 24                Discount Store                     Dive Bar
# 25            Dim Sum Restaurant                        Diner
# 26              Basketball Court  Eastern European Restaurant
# 27                    Restaurant           Dim Sum Restaurant
# 28                         Diner         Fast Food Restaurant
# 29              Doner Restaurant                        Diner
# 31                 Women's Store                      Dog Run
# 32   Eastern European Restaurant          Dumpling Restaurant
# 33            Dim Sum Restaurant                        Diner
# 34                   Pizza Place  Eastern European Restaurant
# 35                  Intersection                     Pharmacy
# 36              Asian Restaurant                 Dance Studio
# 37            Dim Sum Restaurant                        Diner
# 38                  Dessert Shop                   Beer Store
# 39                      Pharmacy                  Pizza Place
# 41                   Pizza Place                          Spa
# 42                  Burger Joint                Burrito Place
# 43                        Bakery                  Yoga Studio
# 44              Doner Restaurant                        Diner
# 45             Food & Drink Shop                         Park
# 46            Mexican Restaurant                 Dessert Shop
# 47                          Café           Italian Restaurant
# 48                         Diner               Discount Store
# 49              Sushi Restaurant                   Restaurant
# 51                          Café           Italian Restaurant
# 52                  Burger Joint              Bubble Tea Shop
# 53                       Theater                         Café
# 54          Fast Food Restaurant                   Restaurant
# 55                Breakfast Spot                       Bakery
# 56                   Cheese Shop                         Café
# 57                  Burger Joint           Chinese Restaurant
# 58                           Bar             Sushi Restaurant
# 59           Sporting Goods Shop                  Pizza Place
# 60           American Restaurant                    Gastropub
# 61                    Steakhouse                          Gym
# 62             Indian Restaurant             Sushi Restaurant
# 63                         Diner               Discount Store
# 64           Dumpling Restaurant                    Drugstore
# 65           American Restaurant            Indian Restaurant
# 66                     Bookstore                  Yoga Studio
# 67           Dumpling Restaurant           Mexican Restaurant
# 68                         Plane             Sculpture Garden
# 69                        Bakery                        Hotel
# 70                           Bar             Asian Restaurant
# 71            Miscellaneous Shop                    Gift Shop
# 72                       Dog Run           Dim Sum Restaurant
# 73                  Dessert Shop           Dim Sum Restaurant
# 75                    Baby Store                    Nightclub
# 76                           Bar    Middle Eastern Restaurant
# 77                   Men's Store                  Pizza Place
# 78                 Burrito Place                   Restaurant
# 80                  Dessert Shop           Dim Sum Restaurant
# 81                 Women's Store             Doner Restaurant
# 82                        Bakery    Cajun / Creole Restaurant
# 83                       Dog Run                          Bar
# 84                  Gourmet Shop            Electronics Store
# 85            Seafood Restaurant               Sandwich Place
# 86                Sandwich Place          Fried Chicken Joint
# 87                    Smoke Shop                Burrito Place
# 88          Fast Food Restaurant                   Restaurant
# 89                Sandwich Place                         Pool
# 92        Thrift / Vintage Store            Convenience Store
# 93                             0                            0
# 94                         Diner               Discount Store
# 95             Convenience Store                         Café
# 97                      Dive Bar                      Dog Run
# 99     Middle Eastern Restaurant                Women's Store
# 100                      Dog Run           Dim Sum Restaurant
# 101                   Beer Store                  Pizza Place
# 102                        Diner               Discount Store
#
#          8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0                      Dog Run      Doner Restaurant              Drugstore
# 2                 Intersection             Drugstore             Donut Shop
# 3                      Dog Run      Doner Restaurant          Women's Store
# 4                      Dog Run                 Diner         Discount Store
# 5               Discount Store              Dive Bar                Dog Run
# 6                        Diner              Dive Bar                Dog Run
# 7          Dumpling Restaurant             Drugstore             Donut Shop
# 8                     Dive Bar               Dog Run          Women's Store
# 9               Discount Store              Dive Bar                Dog Run
# 10          Dim Sum Restaurant                 Diner         Discount Store
# 11              Discount Store              Dive Bar                Dog Run
# 12              Discount Store              Dive Bar                Dog Run
# 13          Chinese Restaurant       Thai Restaurant               Dive Bar
# 15                    Pharmacy           Pizza Place         Breakfast Spot
# 16                           0                     0                      0
# 17          Dim Sum Restaurant                 Diner         Discount Store
# 18                      Bakery            Restaurant          Movie Theater
# 19              Discount Store              Dive Bar       Doner Restaurant
# 21                           0                     0                      0
# 22       Indonesian Restaurant                 Hotel         Ice Cream Shop
# 24            Department Store          Dessert Shop     Dim Sum Restaurant
# 25              Discount Store              Dive Bar                Dog Run
# 26         Dumpling Restaurant             Drugstore                  Diner
# 27              Discount Store   Sporting Goods Shop         Sandwich Place
# 28                 Supermarket        Sandwich Place               Pharmacy
# 29              Discount Store              Dive Bar                Dog Run
# 31          Dim Sum Restaurant                 Diner         Discount Store
# 32                   Drugstore            Donut Shop     Dim Sum Restaurant
# 33                    Dive Bar               Dog Run       Doner Restaurant
# 34         Dumpling Restaurant             Drugstore             Donut Shop
# 35              Breakfast Spot                  Bank   Gym / Fitness Center
# 36                    Pharmacy            Comic Shop           Concert Hall
# 37              Discount Store              Dive Bar                Dog Run
# 38              Sandwich Place           Supermarket                   Bank
# 39              Sandwich Place          Burger Joint                   Bank
# 41                   Bookstore               Brewery        Bubble Tea Shop
# 42        Fast Food Restaurant     Fish & Chips Shop     Italian Restaurant
# 43              Sandwich Place                   Bar       Stationery Store
# 44              Discount Store              Dive Bar                Dog Run
# 45                   Gift Shop     German Restaurant           Gourmet Shop
# 46                        Park    Chinese Restaurant    Rental Car Location
# 47            Sushi Restaurant   Fried Chicken Joint             Restaurant
# 48                    Dive Bar               Dog Run          Women's Store
# 49                Liquor Store   Fried Chicken Joint             Sports Bar
# 51           Indian Restaurant  Caribbean Restaurant          Deli / Bodega
# 52                         Pub                  Café                  Hotel
# 53                  Restaurant    Mexican Restaurant   Gym / Fitness Center
# 54                   Bookstore                 Diner         Lingerie Store
# 55                   Gastropub    Italian Restaurant               Creperie
# 56              Farmers Market    Seafood Restaurant              Jazz Club
# 57   Middle Eastern Restaurant                   Bar                    Spa
# 58            Asian Restaurant                Bakery                  Hotel
# 59                      Bakery        Scenic Lookout                Brewery
# 60                         Bar                   Gym          Deli / Bodega
# 61                   Gastropub    Seafood Restaurant                 Bakery
# 62         Japanese Restaurant  Fast Food Restaurant              Juice Bar
# 63                    Dive Bar               Dog Run       Doner Restaurant
# 64                  Donut Shop      Doner Restaurant       Department Store
# 65               Metro Station                   Pub      Jewish Restaurant
# 66          Italian Restaurant              Beer Bar             Beer Store
# 67                      Bakery           Coffee Shop                   Park
# 68                    Boutique                   Bar          Boat or Ferry
# 69          Seafood Restaurant          Cocktail Bar            Cheese Shop
# 70                  Restaurant         Deli / Bodega                 Bakery
# 71                 Event Space     Accessories Store  Vietnamese Restaurant
# 72                       Diner        Discount Store               Dive Bar
# 73                       Diner        Discount Store               Dive Bar
# 75           Convenience Store                 Diner             Restaurant
# 76                    Bus Stop        Discount Store                   Bank
# 77                Cocktail Bar     French Restaurant                 Bakery
# 78        Caribbean Restaurant          Climbing Gym            Yoga Studio
# 80                       Diner        Discount Store               Dive Bar
# 81                       Diner        Discount Store               Dive Bar
# 82                 Flea Market                 Diner    Fried Chicken Joint
# 83                        Bank    Italian Restaurant           Dessert Shop
# 84         Indie Movie Theater                   Bar      Fish & Chips Shop
# 85                Burger Joint         Burrito Place                   Café
# 86               Burrito Place    Dim Sum Restaurant                  Diner
# 87                         Spa        Farmers Market   Fast Food Restaurant
# 88          Seafood Restaurant                Bakery            Pizza Place
# 89                         Pub        Discount Store       Department Store
# 92                 Social Club          Burger Joint   Fast Food Restaurant
# 93                           0                     0                      0
# 94                    Dive Bar               Dog Run             Donut Shop
# 95                 Pizza Place              Pharmacy           Dessert Shop
# 97            Doner Restaurant            Donut Shop       Department Store
# 99                Dessert Shop    Dim Sum Restaurant                  Diner
# 100                      Diner        Discount Store               Dive Bar
# 101                   Pharmacy   Dumpling Restaurant              Drugstore
# 102                   Dive Bar               Dog Run       Doner Restaurant

# %% [markdown]
# ###### C2 : Cafeteria zone

# %%
toronto_merged.loc[toronto_merged['ClusterL'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#        Borough  ClusterL 1st Most Common Venue 2nd Most Common Venue  \
# 20  North York         1             Cafeteria      Doner Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 20          Dessert Shop    Dim Sum Restaurant                 Diner
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 20        Discount Store              Dive Bar               Dog Run
#
#    9th Most Common Venue 10th Most Common Venue
# 20         Women's Store       Department Store

# %% [markdown]
# ###### C3 : Gym and park zone

# %%
toronto_merged.loc[toronto_merged['ClusterL'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  ClusterL 1st Most Common Venue 2nd Most Common Venue  \
# 14       Scarborough         2                   Gym                  Park
# 23        North York         2                  Park     Convenience Store
# 30        North York         2                  Park               Airport
# 40         East York         2                  Park     Convenience Store
# 50  Downtown Toronto         2                  Park            Playground
# 74              York         2                  Park         Women's Store
# 79        North York         2                  Park                Bakery
# 90         Etobicoke         2                 River                  Park
# 91         Etobicoke         2                  Park                  Pool
# 98              York         2                  Park         Women's Store
#
#          3rd Most Common Venue 4th Most Common Venue  \
# 14                  Playground      Doner Restaurant
# 23                        Bank            Donut Shop
# 30               Women's Store            Donut Shop
# 40                 Pizza Place           Coffee Shop
# 50                    Building                 Trail
# 74        Fast Food Restaurant                Market
# 79  Construction & Landscaping         Women's Store
# 90               Women's Store               Dog Run
# 91              Baseball Field         Women's Store
# 98                  Donut Shop    Dim Sum Restaurant
#
#           5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 14                 Dessert Shop    Dim Sum Restaurant                 Diner
# 23                        Diner        Discount Store              Dive Bar
# 30           Dim Sum Restaurant                 Diner        Discount Store
# 40                Women's Store    Dim Sum Restaurant                 Diner
# 50  Eastern European Restaurant     Electronics Store   Dumpling Restaurant
# 74                     Pharmacy           Golf Course      Greek Restaurant
# 79                   Donut Shop                 Diner        Discount Store
# 90                 Dessert Shop    Dim Sum Restaurant                 Diner
# 91             Doner Restaurant    Dim Sum Restaurant                 Diner
# 98                        Diner        Discount Store              Dive Bar
#
#           8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 14               Discount Store              Dive Bar                Dog Run
# 23                      Dog Run      Doner Restaurant          Women's Store
# 30                     Dive Bar               Dog Run       Doner Restaurant
# 40               Discount Store              Dive Bar                Dog Run
# 50                    Drugstore            Donut Shop          Deli / Bodega
# 74  Eastern European Restaurant   Dumpling Restaurant              Drugstore
# 79                     Dive Bar               Dog Run       Doner Restaurant
# 90               Discount Store              Dive Bar       Doner Restaurant
# 91               Discount Store              Dive Bar                Dog Run
# 98                      Dog Run      Doner Restaurant              Drugstore

# %% [markdown]
# ###### C4 : Food zone

# %%
toronto_merged.loc[toronto_merged['ClusterL'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#        Borough  ClusterL 1st Most Common Venue 2nd Most Common Venue  \
# 96  North York         3   Empanada Restaurant         Women's Store
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 96      Doner Restaurant          Dessert Shop    Dim Sum Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 96                 Diner        Discount Store              Dive Bar
#
#    9th Most Common Venue 10th Most Common Venue
# 96               Dog Run             Donut Shop

# %% [markdown]
# ###### C5 : Women's zone due stores and dessert/donut shops

# %%
toronto_merged.loc[toronto_merged['ClusterL'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#        Borough  ClusterL 1st Most Common Venue 2nd Most Common Venue  \
# 1  Scarborough         4                   Bar         Women's Store
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 1            Donut Shop                 Diner        Discount Store
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 1              Dive Bar               Dog Run      Doner Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 1             Drugstore           Dessert Shop
